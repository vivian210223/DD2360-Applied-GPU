# %%
# !nvidia-smi
# Out:
# Mon Nov 27 13:50:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/NVIDIA/cuda-samples.git
# Out:
# Cloning into 'cuda-samples'...
# remote: Enumerating objects: 16830, done.
# remote: Counting objects: 100% (2488/2488), done.
# remote: Compressing objects: 100% (322/322), done.
# remote: Total 16830 (delta 2211), reused 2190 (delta 2166), pack-reused 14342
# Receiving objects: 100% (16830/16830), 133.20 MiB | 19.88 MiB/s, done.
# Resolving deltas: 100% (14273/14273), done.
# Updating files: 100% (3997/3997), done.

# %%
# !ls cuda-samples/
# Out:
# bin	      Common   Makefile   Samples	      Samples_VS2019.sln
# CHANGELOG.md  LICENSE  README.md  Samples_VS2017.sln  Samples_VS2022.sln

# %%
# %cd /content/cuda-samples/Samples/1_Utilities/deviceQuery
# Out:
# /content/cuda-samples/Samples/1_Utilities/deviceQuery

# %%
# !make deviceQuery
# Out:
# /usr/local/cuda/bin/nvcc -ccbin g++ -I../../../Common -m64 --threads 0 --std=c++11 -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_70,code=sm_70 -gencode arch=compute_75,code=sm_75 -gencode arch=compute_80,code=sm_80 -gencode arch=compute_86,code=sm_86 -gencode arch=compute_89,code=sm_89 -gencode arch=compute_90,code=sm_90 -gencode arch=compute_90,code=compute_90 -o deviceQuery.o -c deviceQuery.cpp
# /usr/local/cuda/bin/nvcc -ccbin g++ -m64 -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_70,code=sm_70 -gencode arch=compute_75,code=sm_75 -gencode arch=compute_80,code=sm_80 -gencode arch=compute_86,code=sm_86 -gencode arch=compute_89,code=sm_89 -gencode arch=compute_90,code=sm_90 -gencode arch=compute_90,code=compute_90 -o deviceQuery deviceQuery.o
# ...

# %%
! ./deviceQuery
# Out:
# ./deviceQuery Starting...
#
#  CUDA Device Query (Runtime API) version (CUDART static linking)
#
# Detected 1 CUDA Capable device(s)
#
# Device 0: "Tesla T4"
#   CUDA Driver Version / Runtime Version          12.0 / 11.8
#   CUDA Capability Major/Minor version number:    7.5
#   Total amount of global memory:                 15102 MBytes (15835398144 bytes)
#   (040) Multiprocessors, (064) CUDA Cores/MP:    2560 CUDA Cores
#   GPU Max Clock rate:                            1590 MHz (1.59 GHz)
#   Memory Clock rate:                             5001 Mhz
#   Memory Bus Width:                              256-bit
#   L2 Cache Size:                                 4194304 bytes
#   Maximum Texture Dimension Size (x,y,z)         1D=(131072), 2D=(131072, 65536), 3D=(16384, 16384, 16384)
#   Maximum Layered 1D Texture Size, (num) layers  1D=(32768), 2048 layers
#   Maximum Layered 2D Texture Size, (num) layers  2D=(32768, 32768), 2048 layers
# ...

# %%
# %cd /content/cuda-samples/Samples/1_Utilities/bandwidthTest/
# Out:
# /content/cuda-samples/Samples/1_Utilities/bandwidthTest

# %%
# !make bandwidthTest
# Out:
# make: 'bandwidthTest' is up to date.

# %%
! ./bandwidthTest
# Out:
# [CUDA Bandwidth Test] - Starting...
# Running on...
#
#  Device 0: Tesla T4
#  Quick Mode
#
#  Host to Device Bandwidth, 1 Device(s)
#  PINNED Memory Transfers
#    Transfer Size (Bytes)	Bandwidth(GB/s)
#    32000000			11.7
#
#  Device to Host Bandwidth, 1 Device(s)
#  PINNED Memory Transfers
#    Transfer Size (Bytes)	Bandwidth(GB/s)
#    32000000			12.8
#
#  Device to Device Bandwidth, 1 Device(s)
#  PINNED Memory Transfers
#    Transfer Size (Bytes)	Bandwidth(GB/s)
#    32000000			239.4
#
# Result = PASS
#
# NOTE: The CUDA Samples are not meant for performance measurements. Results may vary when GPU Boost is enabled.

# %%
# !wget http://www.cs.virginia.edu/~skadron/lava/Rodinia/Packages/rodinia_3.1.tar.bz2
# Out:
# --2023-11-27 13:51:20--  http://www.cs.virginia.edu/~skadron/lava/Rodinia/Packages/rodinia_3.1.tar.bz2
# Resolving www.cs.virginia.edu (www.cs.virginia.edu)... 128.143.67.11
# Connecting to www.cs.virginia.edu (www.cs.virginia.edu)|128.143.67.11|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.cs.virginia.edu/~skadron/lava/Rodinia/Packages/rodinia_3.1.tar.bz2 [following]
# --2023-11-27 13:51:20--  https://www.cs.virginia.edu/~skadron/lava/Rodinia/Packages/rodinia_3.1.tar.bz2
# Connecting to www.cs.virginia.edu (www.cs.virginia.edu)|128.143.67.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 360636246 (344M) [application/x-tar]
# Saving to: ‘rodinia_3.1.tar.bz2’
#
# rodinia_3.1.tar.bz2 100%[===================>] 343.93M  74.2MB/s    in 4.9s
#
# 2023-11-27 13:51:26 (70.5 MB/s) - ‘rodinia_3.1.tar.bz2’ saved [360636246/360636246]

# %%
# !tar jxvf rodinia_3.1.tar.bz2
# Out:
# rodinia_3.1/
# rodinia_3.1/LICENSE
# rodinia_3.1/cuda/
# rodinia_3.1/cuda/huffman/
# rodinia_3.1/cuda/huffman/cpuencode.h
# rodinia_3.1/cuda/huffman/pack_kernels.cu
# rodinia_3.1/cuda/huffman/scan.cu
# rodinia_3.1/cuda/huffman/vlc_kernel_sm64huff.cu
# rodinia_3.1/cuda/huffman/parameters.h
# rodinia_3.1/cuda/huffman/load_data.h
# rodinia_3.1/cuda/huffman/cpuencode.cpp
# rodinia_3.1/cuda/huffman/hist.cu
# rodinia_3.1/cuda/huffman/scanLargeArray_kernel.cu
# rodinia_3.1/cuda/huffman/cutil.h
# rodinia_3.1/cuda/huffman/stats_logger.cpp
# rodinia_3.1/cuda/huffman/comparison_helpers.h
# rodinia_3.1/cuda/huffman/stdafx.h
# rodinia_3.1/cuda/huffman/cuda_helpers.h
# rodinia_3.1/cuda/huffman/testdatagen.h
# rodinia_3.1/cuda/huffman/main_test_cu.cu
# rodinia_3.1/cuda/huffman/pabio_kernels_v2.cu
# rodinia_3.1/cuda/huffman/Makefile
# rodinia_3.1/cuda/huffman/huffTree.h
# rodinia_3.1/cuda/huffman/stats_logger.h
# rodinia_3.1/cuda/huffman/print_helpers.h
# rodinia_3.1/cuda/huffman/run
# ...

# %%
# %cd /content/rodinia_3.1/cuda/backprop
# Out:
# /content/rodinia_3.1/cuda/backprop

# %%
# !make clean
# Out:
# rm -rf *.o nn hurricane_gen

# %%
# !make backprop
# Out:
# make: 'backprop' is up to date.

# %%
! ls
# Out:
# backprop	  backprop_cuda_kernel.cu  backprop.o	imagenet.c  Makefile_nvidia
# backprop.c	  backprop_cuda.o	   facetrain.c	imagenet.o  run
# backprop_cuda.cu  backprop.h		   facetrain.o	Makefile

# %%
# !./run
# Out:
# ./backprop: error while loading shared libraries: libcudart.so.7.0: cannot open shared object file: No such file or directory

# %%
# !./nn filelist_4 -r 5 -lat 30 -lng 90
# Out:
# 1988 12 27  0 18 TONY       30.0  89.8  113   39 --> Distance=0.199997
# 1980 10 22 18  3 ISAAC      30.1  90.4  110  778 --> Distance=0.412312
# 1997 11 14 12 24 HELENE     30.5  89.8  134  529 --> Distance=0.538515
# 2003  8 27 12 10 TONY       29.9  89.4  160  286 --> Distance=0.608275
# 1974 12 22 18 24 JOYCE      30.6  89.9   80  593 --> Distance=0.608276
#
# real	0m0.148s
# user	0m0.024s
# sys	0m0.117s

# %%
# !nvprof ./nn filelist_4 -r 5 -lat 30 -lng 90 --timeout
# Out:
# ==6199== NVPROF is profiling process 6199, command: ./nn filelist_4 -r 5 -lat 30 -lng 90 --timeout
# 1988 12 27  0 18 TONY       30.0  89.8  113   39 --> Distance=0.199997
# 1980 10 22 18  3 ISAAC      30.1  90.4  110  778 --> Distance=0.412312
# 1997 11 14 12 24 HELENE     30.5  89.8  134  529 --> Distance=0.538515
# 2003  8 27 12 10 TONY       29.9  89.4  160  286 --> Distance=0.608275
# 1974 12 22 18 24 JOYCE      30.6  89.9   80  593 --> Distance=0.608276
# ==6199== Profiling application: ./nn filelist_4 -r 5 -lat 30 -lng 90 --timeout
# ==6199== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   55.94%  30.879us         1  30.879us  30.879us  30.879us  [CUDA memcpy HtoD]
#                    32.58%  17.983us         1  17.983us  17.983us  17.983us  [CUDA memcpy DtoH]
#                    11.48%  6.3360us         1  6.3360us  6.3360us  6.3360us  euclid(latLong*, float*, int, float, float)
# ...

# %%
# %cd /content/rodinia_3.1/openmp/nn
# Out:
# /content/rodinia_3.1/openmp/nn

# %%
# !make nn
# Out:
# make: 'nn' is up to date.

# %%
# !./nn filelist_4 5 30 90
# Out:
# The 5 nearest neighbors are:
# 1974 12 22 18 24 JOYCE      30.6  89.9   80  593 --> 0.608276
# 2003  8 27 12 10 TONY       29.9  89.4  160  286 --> 0.608275
# 1997 11 14 12 24 HELENE     30.5  89.8  134  529 --> 0.538515
# 1980 10 22 18  3 ISAAC      30.1  90.4  110  778 --> 0.412312
# 1988 12 27  0 18 TONY       30.0  89.8  113   39 --> 0.199997
# total time :  0.039179001004 s

# %%
# !time ./nn filelist_4 5 30 90
# Out:
# The 5 nearest neighbors are:
# 1974 12 22 18 24 JOYCE      30.6  89.9   80  593 --> 0.608276
# 2003  8 27 12 10 TONY       29.9  89.4  160  286 --> 0.608275
# 1997 11 14 12 24 HELENE     30.5  89.8  134  529 --> 0.538515
# 1980 10 22 18  3 ISAAC      30.1  90.4  110  778 --> 0.412312
# 1988 12 27  0 18 TONY       30.0  89.8  113   39 --> 0.199997
# total time :  0.044135000557 s
# real	0m0.028s
# user	0m0.043s
# sys	0m0.003s

# %%
# %cd /content/rodinia_3.1/cuda/bfs
# Out:
# /content/rodinia_3.1/cuda/bfs

# %%
# !time ./bfs ../../data/bfs/graph1MW_6.txt
# Out:
# Reading File
# Read File
# Copied Everything to GPU memory
# Start traversing the tree
# Kernel Executed 12 times
# Result stored in result.txt
#
# real	0m1.541s
# user	0m1.330s
# sys	0m0.187s

# %%
# !nvprof ./bfs ../../data/bfs/graph1MW_6.txt
# Out:
# Reading File
# Read File
# ==14602== NVPROF is profiling process 14602, command: ./bfs ../../data/bfs/graph1MW_6.txt
# Copied Everything to GPU memory
# Start traversing the tree
# Kernel Executed 12 times
# Result stored in result.txt
# ==14602== Profiling application: ./bfs ../../data/bfs/graph1MW_6.txt
# ==14602== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   65.27%  7.5656ms        18  420.31us  1.3120us  4.9478ms  [CUDA memcpy HtoD]
#                    26.56%  3.0786ms        12  256.55us  36.415us  1.1351ms  Kernel(Node*, int*, bool*, bool*, bool*, int*, int)
#                     4.19%  485.59us        13  37.353us  1.6000us  465.14us  [CUDA memcpy DtoH]
#                     3.98%  461.46us        12  38.455us  31.711us  46.591us  Kernel2(bool*, bool*, bool*, bool*, int)
#       API calls:   89.18%  125.97ms         7  17.996ms  8.7730us  125.38ms  cudaMalloc
# ...

# %%
# %cd /content/rodinia_3.1/openmp/bfs
# Out:
# /content/rodinia_3.1/openmp/bfs

# %%
# !make bfs
# Out:
# make: 'bfs' is up to date.

# %%
# !time ./bfs 4 ../../data/bfs/graph1MW_6.txt
# Out:
# Reading File
# Start traversing the tree
# Compute time: 0.284244
# Result stored in result.txt
#
# real	0m2.928s
# user	0m2.833s
# sys	0m0.046s
