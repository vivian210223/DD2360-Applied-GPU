# %%
# !nvidia-smi
# Out:
# Tue Dec 26 23:20:51 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DD2360\ Applied\ GPU/4/
# Out:
# /content/drive/MyDrive/DD2360 Applied GPU/4

# %% [markdown]
# streamed version with different vector length ( with 8 streams)

# %%
# !nvcc -o ex2.out ex2.cu

# %%
! nvprof --output-profile stream.nvvp -f ./ex2.out 1048576 512
# Out:
# The input length is 1048576
# ==10779== NVPROF is profiling process 10779, command: ./ex2.out 1048576 512
# Time: 0.012901 (s)
# ==10779== Generated result file: /content/drive/MyDrive/DD2360 Applied GPU/4/stream.nvvp
# The output is equal to the reference

# %%
! ./ex2.out 65536 512
# Out:
# The input length is 65536
# Time: 0.004307 (s)
# The output is equal to the reference

# %%
! nvprof ./ex2.out 1048576 512
# Out:
# The input length is 1048576
# ==8005== NVPROF is profiling process 8005, command: ./ex2.out 1048576 512
# Time: 0.012228 (s)
# The output is equal to the reference==8005== Profiling application: ./ex2.out 1048576 512
# ==8005== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   65.49%  1.4060ms        16  87.872us  87.486us  88.318us  [CUDA memcpy HtoD]
#                    30.85%  662.39us         8  82.798us  81.854us  84.734us  [CUDA memcpy DtoH]
#                     3.66%  78.590us         8  9.8230us  9.5680us  10.176us  vecAdd(double*, double*, double*, int)
#       API calls:   93.62%  196.35ms         8  24.543ms  1.9980us  196.33ms  cudaStreamCreate
#                     5.39%  11.314ms        24  471.40us  224.22us  973.59us  cudaMemcpyAsync
#                     0.43%  903.59us         3  301.20us  136.81us  392.40us  cudaFree
# ...

# %%
! nvprof ./ex2.out 2097152 512
# Out:
# The input length is 2097152
# ==8028== NVPROF is profiling process 8028, command: ./ex2.out 2097152 512
# Time: 0.021992 (s)
# The output is equal to the reference==8028== Profiling application: ./ex2.out 2097152 512
# ==8028== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   76.72%  4.9901ms        16  311.88us  299.55us  345.21us  [CUDA memcpy HtoD]
#                    20.82%  1.3544ms         8  169.30us  165.56us  186.56us  [CUDA memcpy DtoH]
#                     2.46%  159.71us         8  19.963us  19.711us  20.320us  vecAdd(double*, double*, double*, int)
#       API calls:   88.65%  186.14ms         8  23.267ms  2.0530us  186.12ms  cudaStreamCreate
#                    10.02%  21.032ms        24  876.35us  433.79us  1.7844ms  cudaMemcpyAsync
#                     0.76%  1.6012ms         3  533.72us  143.45us  738.01us  cudaFree
# ...

# %%
! nvprof ./ex2.out 65536 512
# Out:
# The input length is 65536
# ==5992== NVPROF is profiling process 5992, command: ./ex2.out 65536 512
# Time: 0.001941 (s)
# ==5992== Profiling application: ./ex2.out 65536 512
# ==5992== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   63.46%  147.77us        16  9.2350us  8.2870us  11.232us  [CUDA memcpy HtoD]
#                    22.62%  52.671us         8  6.5830us  6.4320us  6.9760us  [CUDA memcpy DtoH]
#                    13.92%  32.415us         8  4.0510us  3.9680us  4.2880us  vecAdd(double*, double*, double*, int)
#       API calls:   98.97%  218.61ms         8  27.326ms  3.0440us  218.59ms  cudaStreamCreate
#                     0.52%  1.1473ms        24  47.805us  25.319us  86.736us  cudaMemcpyAsync
#                     0.24%  540.97us         8  67.621us  10.328us  457.75us  cudaLaunchKernel
#                     0.08%  180.63us       114  1.5840us     197ns  67.713us  cuDeviceGetAttribute
# ...

# %%
! nvprof ./ex2.out 262144 512
# Out:
# The input length is 262144
# ==6007== NVPROF is profiling process 6007, command: ./ex2.out 262144 512
# Time: 0.004065 (s)
# The output is equal to the reference==6007== Profiling application: ./ex2.out 262144 512
# ==6007== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   64.97%  404.31us        16  25.269us  23.967us  27.071us  [CUDA memcpy HtoD]
#                    28.22%  175.61us         8  21.951us  21.312us  23.040us  [CUDA memcpy DtoH]
#                     6.80%  42.335us         8  5.2910us  5.2160us  5.3440us  vecAdd(double*, double*, double*, int)
#       API calls:   97.64%  210.80ms         8  26.350ms  3.1090us  210.77ms  cudaStreamCreate
#                     1.57%  3.3948ms        24  141.45us  61.895us  321.63us  cudaMemcpyAsync
#                     0.29%  619.34us         8  77.417us  17.214us  477.92us  cudaLaunchKernel
# ...

# %%
! nvprof ./ex2.out 16384 512
# Out:
# The input length is 16384
# ==6018== NVPROF is profiling process 6018, command: ./ex2.out 16384 512
# Time: 0.001097 (s)
# The output is equal to the reference==6018== Profiling application: ./ex2.out 16384 512
# ==6018== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   48.13%  49.566us        16  3.0970us  2.8790us  3.6480us  [CUDA memcpy HtoD]
#                    29.96%  30.846us         8  3.8550us  3.7760us  4.1280us  vecAdd(double*, double*, double*, int)
#                    21.91%  22.561us         8  2.8200us  2.6560us  3.2000us  [CUDA memcpy DtoH]
#       API calls:   99.23%  164.57ms         8  20.571ms  1.8140us  164.55ms  cudaStreamCreate
#                     0.27%  450.28us        24  18.761us  7.4590us  39.657us  cudaMemcpyAsync
#                     0.24%  391.62us         8  48.952us  4.5810us  350.45us  cudaLaunchKernel
# ...

# %% [markdown]
# non-streamed version with different vector length

# %%
# %cd /content/drive/MyDrive/DD2360\ Applied\ GPU/2/
# Out:
# /content/drive/MyDrive/DD2360 Applied GPU/2

# %%
# !nvcc -o ex1.out ex1.cu

# %%
! nvprof ./ex1.out 2097152 512
# Out:
# The input length is 2097152
# ==6077== NVPROF is profiling process 6077, command: ./ex1.out 2097152 512
# Time: 0.034676 (s)
# The output is equal to the reference==6077== Profiling application: ./ex1.out 2097152 512
# ==6077== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   55.58%  17.173ms         1  17.173ms  17.173ms  17.173ms  [CUDA memcpy DtoH]
#                    43.82%  13.540ms         3  4.5134ms  3.4943ms  6.3527ms  [CUDA memcpy HtoD]
#                     0.60%  186.08us         1  186.08us  186.08us  186.08us  vecAdd(double*, double*, double*, int)
#       API calls:   85.34%  211.55ms         3  70.516ms  122.81us  211.26ms  cudaMalloc
#                    13.73%  34.022ms         4  8.5055ms  3.7085ms  19.629ms  cudaMemcpy
#                     0.67%  1.6610ms         3  553.67us  167.83us  768.22us  cudaFree
# ...

# %%
! nvprof ./ex1.out 1048576 512
# Out:
# The input length is 1048576
# ==6088== NVPROF is profiling process 6088, command: ./ex1.out 1048576 512
# Time: 0.022552 (s)
# ==6088== Profiling application: ./ex1.out 1048576 512
# ==6088== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   51.36%  7.6362ms         1  7.6362ms  7.6362ms  7.6362ms  [CUDA memcpy DtoH]
#                    48.03%  7.1403ms         3  2.3801ms  1.8325ms  3.4403ms  [CUDA memcpy HtoD]
#                     0.61%  90.718us         1  90.718us  90.718us  90.718us  vecAdd(double*, double*, double*, int)
#       API calls:   90.50%  198.47ms         3  66.158ms  126.27us  198.20ms  cudaMalloc
#                     8.22%  18.032ms         4  4.5079ms  2.0195ms  10.003ms  cudaMemcpy
#                     0.72%  1.5743ms         1  1.5743ms  1.5743ms  1.5743ms  cudaLaunchKernel
#                     0.44%  955.15us         3  318.38us  163.58us  403.28us  cudaFree
# ...

# %%
! nvprof ./ex1.out 262144 512
# Out:
# The input length is 262144
# ==6103== NVPROF is profiling process 6103, command: ./ex1.out 262144 512
# Time: 0.005190 (s)
# ==6103== Profiling application: ./ex1.out 262144 512
# ==6103== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   84.45%  1.1606ms         3  386.87us  315.99us  525.14us  [CUDA memcpy HtoD]
#                    14.05%  193.02us         1  193.02us  193.02us  193.02us  [CUDA memcpy DtoH]
#                     1.50%  20.640us         1  20.640us  20.640us  20.640us  vecAdd(double*, double*, double*, int)
#       API calls:   97.23%  196.91ms         3  65.636ms  95.466us  196.68ms  cudaMalloc
#                     2.27%  4.5953ms         4  1.1488ms  504.20us  2.5313ms  cudaMemcpy
#                     0.20%  404.67us         3  134.89us  123.93us  155.37us  cudaFree
#                     0.19%  380.93us         1  380.93us  380.93us  380.93us  cudaLaunchKernel
# ...

# %%
! nvprof ./ex1.out 65536 512
# Out:
# The input length is 65536
# ==6114== NVPROF is profiling process 6114, command: ./ex1.out 65536 512
# Time: 0.001998 (s)
# The output is equal to the reference==6114== Profiling application: ./ex1.out 65536 512
# ==6114== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   73.15%  145.18us         3  48.393us  48.319us  48.447us  [CUDA memcpy HtoD]
#                    23.38%  46.399us         1  46.399us  46.399us  46.399us  [CUDA memcpy DtoH]
#                     3.47%  6.8800us         1  6.8800us  6.8800us  6.8800us  vecAdd(double*, double*, double*, int)
#       API calls:   98.87%  184.07ms         3  61.356ms  4.0290us  184.05ms  cudaMalloc
#                     0.73%  1.3573ms         4  339.31us  158.87us  716.31us  cudaMemcpy
#                     0.20%  379.51us         1  379.51us  379.51us  379.51us  cudaLaunchKernel
# ...

# %%
! nvprof ./ex1.out 16384 512
# Out:
# The input length is 16384
# ==6129== NVPROF is profiling process 6129, command: ./ex1.out 16384 512
# Time: 0.001006 (s)
# ==6129== Profiling application: ./ex1.out 16384 512
# ==6129== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   71.49%  41.247us         3  13.749us  12.991us  15.104us  [CUDA memcpy HtoD]
#                    21.13%  12.191us         1  12.191us  12.191us  12.191us  [CUDA memcpy DtoH]
#                     7.38%  4.2560us         1  4.2560us  4.2560us  4.2560us  vecAdd(double*, double*, double*, int)
#       API calls:   99.40%  189.59ms         3  63.198ms  3.3980us  189.59ms  cudaMalloc
#                     0.20%  388.24us         1  388.24us  388.24us  388.24us  cudaLaunchKernel
#                     0.20%  373.48us         4  93.370us  50.708us  184.17us  cudaMemcpy
#                     0.10%  198.35us       114  1.7390us     294ns  74.246us  cuDeviceGetAttribute
# ...

# %% [markdown]
# different number of segment size (number of stream)

# %%
! nvprof ./ex2.out 1048576 1024 4
# Out:
# The input length is 1048576
# ==5752== NVPROF is profiling process 5752, command: ./ex2.out 1048576 1024 4
# Time: 0.013726 (s)
# The output is equal to the reference==5752== Profiling application: ./ex2.out 1048576 1024 4
# ==5752== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   73.74%  2.6155ms         8  326.93us  305.56us  351.42us  [CUDA memcpy HtoD]
#                    23.55%  835.34us         4  208.83us  206.78us  213.53us  [CUDA memcpy DtoH]
#                     2.71%  96.222us         4  24.055us  23.520us  24.320us  vecAdd(double*, double*, double*, int)
#       API calls:   89.17%  125.37ms         4  31.343ms  3.8170us  125.36ms  cudaStreamCreate
#                     9.00%  12.660ms        12  1.0550ms  473.12us  2.2734ms  cudaMemcpyAsync
#                     0.73%  1.0246ms         3  341.52us  205.90us  424.21us  cudaFree
# ...

# %%
! nvprof ./ex2.out 1048576 1024 8
# Out:
# The input length is 1048576
# ==5934== NVPROF is profiling process 5934, command: ./ex2.out 1048576 1024 8
# Time: 0.013365 (s)
# The output is equal to the reference==5934== Profiling application: ./ex2.out 1048576 1024 8
# ==5934== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   60.08%  1.4486ms        16  90.539us  87.710us  91.294us  [CUDA memcpy HtoD]
#                    35.86%  864.52us         8  108.07us  105.89us  111.71us  [CUDA memcpy DtoH]
#                     4.06%  97.883us         8  12.235us  12.096us  12.512us  vecAdd(double*, double*, double*, int)
#       API calls:   85.82%  88.086ms         8  11.011ms  1.9400us  88.068ms  cudaStreamCreate
#                    11.80%  12.116ms        24  504.84us  215.58us  1.0916ms  cudaMemcpyAsync
#                     0.89%  911.00us         3  303.67us  142.98us  388.14us  cudaFree
# ...

# %%
! nvprof ./ex2.out 1048576 1024 16
# Out:
# The input length is 1048576
# ==5856== NVPROF is profiling process 5856, command: ./ex2.out 1048576 1024 16
# Time: 0.012491 (s)
# The output is equal to the reference==5856== Profiling application: ./ex2.out 1048576 1024 16
# ==5856== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   65.86%  1.5435ms        32  48.234us  47.294us  51.359us  [CUDA memcpy HtoD]
#                    28.96%  678.58us        16  42.410us  41.727us  44.607us  [CUDA memcpy DtoH]
#                     5.18%  121.44us        16  7.5890us  7.2000us  7.9360us  vecAdd(double*, double*, double*, int)
#       API calls:   87.72%  97.457ms        16  6.0911ms  1.7540us  97.299ms  cudaStreamCreate
#                    10.39%  11.546ms        48  240.53us  107.18us  563.18us  cudaMemcpyAsync
#                     0.80%  884.58us         3  294.86us  122.08us  388.44us  cudaFree
# ...

# %%
! nvprof ./ex2.out 1048576 1024 32
# Out:
# The input length is 1048576
# ==6420== NVPROF is profiling process 6420, command: ./ex2.out 1048576 1024 32
# Time: 0.012208 (s)
# The output is equal to the reference==6420== Profiling application: ./ex2.out 1048576 1024 32
# ==6420== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   65.89%  1.7026ms        64  26.602us  23.744us  27.967us  [CUDA memcpy HtoD]
#                    28.16%  727.57us        32  22.736us  21.440us  25.215us  [CUDA memcpy DtoH]
#                     5.95%  153.85us        32  4.8070us  4.7030us  5.0240us  vecAdd(double*, double*, double*, int)
#       API calls:   86.04%  83.972ms        32  2.6241ms  1.6240us  83.671ms  cudaStreamCreate
#                    11.91%  11.627ms        96  121.11us  52.774us  280.39us  cudaMemcpyAsync
#                     0.91%  892.13us         3  297.38us  117.64us  401.85us  cudaFree
# ...

# %%
! nvprof ./ex2.out 1048576 1024 64
# Out:
# The input length is 1048576
# ==6783== NVPROF is profiling process 6783, command: ./ex2.out 1048576 1024 64
# Time: 0.013857 (s)
# The output is equal to the reference==6783== Profiling application: ./ex2.out 1048576 1024 64
# ==6783== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   66.00%  1.9960ms       128  15.593us  13.792us  16.959us  [CUDA memcpy HtoD]
#                    24.04%  727.05us        64  11.360us  11.263us  12.096us  [CUDA memcpy DtoH]
#                     9.96%  301.24us        64  4.7060us  4.6080us  5.2480us  vecAdd(double*, double*, double*, int)
#       API calls:   85.89%  92.585ms        64  1.4466ms  1.7270us  90.785ms  cudaStreamCreate
#                    11.68%  12.587ms       192  65.556us  28.502us  156.03us  cudaMemcpyAsync
#                     0.84%  910.64us         3  303.55us  144.17us  393.07us  cudaFree
# ...

# %%
! nvprof ./ex2.out 1048576 1024 2
# Out:
# The input length is 1048576
# ==7012== NVPROF is profiling process 7012, command: ./ex2.out 1048576 1024 2
# Time: 0.015483 (s)
# The output is equal to the reference==7012== Profiling application: ./ex2.out 1048576 1024 2
# ==7012== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   57.54%  4.3257ms         2  2.1628ms  2.1165ms  2.2092ms  [CUDA memcpy DtoH]
#                    41.19%  3.0965ms         4  774.13us  748.65us  799.34us  [CUDA memcpy HtoD]
#                     1.27%  95.806us         2  47.903us  47.839us  47.967us  vecAdd(double*, double*, double*, int)
#       API calls:   86.51%  108.46ms         2  54.231ms  3.8040us  108.46ms  cudaStreamCreate
#                    11.65%  14.604ms         6  2.4340ms  929.40us  6.8580ms  cudaMemcpyAsync
#                     0.82%  1.0279ms         3  342.64us  190.61us  424.25us  cudaFree
# ...

# %%
! nvprof ./ex2.out 1048576 1024 1
# Out:
# The input length is 1048576
# ==7408== NVPROF is profiling process 7408, command: ./ex2.out 1048576 1024 1
# Time: 0.010272 (s)
# The output is equal to the reference==7408== Profiling application: ./ex2.out 1048576 1024 1
# ==7408== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   57.82%  4.5284ms         1  4.5284ms  4.5284ms  4.5284ms  [CUDA memcpy DtoH]
#                    40.96%  3.2080ms         2  1.6040ms  1.5954ms  1.6126ms  [CUDA memcpy HtoD]
#                     1.22%  95.646us         1  95.646us  95.646us  95.646us  vecAdd(double*, double*, double*, int)
#       API calls:   88.96%  92.118ms         1  92.118ms  92.118ms  92.118ms  cudaStreamCreate
#                     9.24%  9.5703ms         3  3.1901ms  1.7764ms  5.9990ms  cudaMemcpyAsync
#                     0.88%  908.56us         3  302.85us  155.18us  386.14us  cudaFree
# ...
